# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiSakamoto/QuTIP_models/blob/master/simple_rabi_oscillation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qutip
# Out:
# ...
#      |████████████████████████████████| 5.5MB 3.7MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/7d/f1/a4/f5687d0ab63c65cd818a29e7826f6ad677887730290476aabc
# Successfully built qutip
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from qutip import *

# %%
# set up the Hamiltonian
Bz = 5
B = 1
u = 1.0
H = u * ( Bz * sigmaz() + B * sigmax() )
print(H)

psi0 = basis(2,0)
tlist = np.linspace(0, 50, 500)
result = mesolve(H, psi0,tlist,[],[sigmaz(), sigmax()])

fig, ax = plt.subplots(figsize=(8,5))
ax.plot(tlist, result.expect[0], label="z")
ax.plot(tlist, result.expect[1], label="x")
fig.legend()
fig.show()
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 5.  1.]
#  [ 1. -5.]]
